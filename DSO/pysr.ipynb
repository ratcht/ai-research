# %%
from pysr import PySRRegressor

# %%
import numpy as np
import pandas as pd

X = np.array([[1], [2], [3], [4], [5]])
y = np.array([3.1416, 12.5664, 28.2743, 50.2655, 78.5398])

pd.DataFrame(columns=["x0", "y"], data=np.column_stack([X, y]))
# Out:
#     x0        y
# 0  1.0   3.1416
# 1  2.0  12.5664
# 2  3.0  28.2743
# 3  4.0  50.2655
# 4  5.0  78.5398

# %%
from pysr import PySRRegressor

model = PySRRegressor(
  niterations=40,  # < Increase me for better results
  binary_operators=["+", "*", "-", "/"],
  unary_operators=[
    "cos",
    "exp",
    "sin",
    "inv(x) = 1/x",
    # ^ Custom operator (julia syntax)
  ],
  extra_sympy_mappings={"inv": lambda x: 1 / x},
  # ^ Define operator for SymPy as well
  elementwise_loss="loss(prediction, target) = (prediction - target)^2",
  # ^ Custom loss function (julia syntax)
)

model.fit(X, y)
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# /Users/alialh/Development/AI Lab/DSO/.venv/lib/python3.8/site-packages/pysr/sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
# [ Info: Started!
# PySRRegressor.equations_ = [
# 	   pick      score                              equation          loss  \
# 	0         0.000000                                    x0  1.660725e+03
# 	1         0.508235                               exp(x0)  9.990197e+02
# 	2         2.156951                        x0 * 12.851971  1.155639e+02
# 	3  >>>>  13.066608                  x0 * (3.141592 * x0)  5.167863e-10
# 	4         0.067141  (x0 * (3.141592 * x0)) + 8.121609e-6  4.518483e-10
#
# 	   complexity
# 	0           1
# 	1           2
# 	2           3
# 	3           5
# 	4           7
# ]

# %%
print(model.equations["equation"][9])

# %% [markdown]
# ## Feynman Dataset

# %%
def generate_column_names(num_columns):
  """
  Generates column names as x1, x2, ..., y based on the number of columns.
  
  Parameters:
      num_columns (int): Total number of columns in the DataFrame.
  
  Returns:
      list: List of column names.
  """
  if num_columns < 2:
      raise ValueError("There should be at least one input variable and one target variable.")
  
  input_columns = [f'x{i}' for i in range(1, num_columns)]
  input_columns.append('y')  # Assuming the last column is the target variable
  return input_columns

# %%
def load_single_file(file_path):
  """
  Loads a single dataset file into a pandas DataFrame with appropriate column names.
  
  Parameters:
      file_path (str): Path to the dataset file.
  
  Returns:
      pandas.DataFrame: Loaded DataFrame with column headers.
  """
  try:
    # Detect the delimiter
    delimiter = "\s+"
    
    # Read the file without headers
    df = pd.read_csv(file_path, sep=delimiter, header=None, engine='python')
    
    # Generate column names
    column_names = generate_column_names(df.shape[1])
    df.columns = column_names
    
    return df
  except Exception as e:
    print(f"Error loading {file_path}: {e}")
    return None

# %%
import os
import pandas as pd

# Answer key for the Feynman equations
equations = pd.read_csv("datasets/FeynmanEquations.csv")

# Path to your dataset directory
dataset_dir = 'datasets/Feynman_with_units/'
# dataset_files = os.listdir(dataset_dir)
dataset_files = ["I.6.2a"]

# Iterate through each file in the directory
# for file_name in dataset_files:
#   file_path = os.path.join(dataset_dir, file_name)
  
#   # Attempt to read as comma-separated; fallback to space-separated if needed
#   df = load_single_file(file_path)
  
#   print(f"Loaded {file_name} with shape {df.shape}")
#   print(df.head())  # Display first few rows

filename = dataset_files[0]
file_path = os.path.join(dataset_dir, filename)
problem = load_single_file(file_path)
answer = equations[equations["Filename"] == filename]["Formula"].values[0]

# %%
answer
# Out:
# 'exp(-theta**2/2)/sqrt(2*pi)'

# %%
X = problem[["x1"]].to_numpy()
y = problem["y"].to_numpy()

# %%
model = PySRRegressor(
  niterations=40,  # < Increase me for better results
  binary_operators=["+", "*", "-", "/"],
  batching=True,
  unary_operators=[
      "cos",
      "exp",
      "sin",
      "inv(x) = 1/x",
      "sqrt"
      # ^ Custom operator (julia syntax)
  ],
  turbo=True,
  progress=True,
  extra_sympy_mappings={"inv": lambda x: 1 / x},
  # ^ Define operator for SymPy as well
  elementwise_loss="loss(prediction, target) = (prediction - target)^2",
  # ^ Custom loss function (julia syntax)
)

model.fit(X, y)
# Out:
# /Users/alialh/Development/AI Lab/DSO/.venv/lib/python3.8/site-packages/pysr/sr.py:2582: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# Compiling Julia backend...
#     Updating registry at `~/.julia/registries/General.toml`
#    Resolving package versions...
#    Installed SIMDTypes ──────────────────────── v0.1.0
#    Installed CpuId ──────────────────────────── v0.3.1
#    Installed OffsetArrays ───────────────────── v1.14.1
#    Installed LayoutPointers ─────────────────── v0.1.17
#    Installed CPUSummary ─────────────────────── v0.2.6
#    Installed BitTwiddlingConvenienceFunctions ─ v0.1.6
#    Installed VectorizationBase ──────────────── v0.21.70
#    Installed LoopVectorization ──────────────── v0.12.171
#    Installed IfElse ─────────────────────────── v0.1.1
#    Installed PolyesterWeave ─────────────────── v0.2.2
#    Installed CloseOpenIntervals ─────────────── v0.1.13
#    Installed ThreadingUtilities ─────────────── v0.5.2
#    Installed ManualMemory ───────────────────── v0.1.8
#    Installed HostCPUFeatures ────────────────── v0.1.17
#    Installed Static ─────────────────────────── v1.1.1
#    Installed SLEEFPirates ───────────────────── v0.6.43
#    Installed CommonWorldInvalidations ───────── v1.0.0
#    Installed StaticArrayInterface ───────────── v1.8.0
#     Updating `~/Development/AI Lab/DSO/.venv/julia_env/Project.toml`
#   [bdcacae8] + LoopVectorization v0.12.171
#     Updating `~/Development/AI Lab/DSO/.venv/julia_env/Manifest.toml`
#   [62783981] + BitTwiddlingConvenienceFunctions v0.1.6
#   [2a0fbf3d] + CPUSummary v0.2.6
#   [fb6a15b2] + CloseOpenIntervals v0.1.13
#   [f70d9fcc] + CommonWorldInvalidations v1.0.0
#   [adafc99b] + CpuId v0.3.1
#   [3e5b6fbb] + HostCPUFeatures v0.1.17
#   [615f187c] + IfElse v0.1.1
#   [10f19ff3] + LayoutPointers v0.1.17
#   [bdcacae8] + LoopVectorization v0.12.171
#   [d125e4d3] + ManualMemory v0.1.8
#   [6fe1bfb0] + OffsetArrays v1.14.1
#   [1d0040c9] + PolyesterWeave v0.2.2
#   [94e857df] + SIMDTypes v0.1.0
#   [476501e8] + SLEEFPirates v0.6.43
#   [aedffcd0] + Static v1.1.1
#   [0d7ed370] + StaticArrayInterface v1.8.0
#   [8290d209] + ThreadingUtilities v0.5.2
#   [3d5dd08c] + VectorizationBase v0.21.70
# Precompiling project...
#   ✓ SIMDTypes
#   ✓ CommonWorldInvalidations
#   ✓ IfElse
#   ✓ ManualMemory
#   ✓ CpuId
#   ✓ OffsetArrays
#   ✓ ThreadingUtilities
#   ✓ OffsetArrays → OffsetArraysAdaptExt
#   ✓ Static
#   ✓ BitTwiddlingConvenienceFunctions
#   ✓ CPUSummary
#   ✓ StaticArrayInterface
#   ✓ HostCPUFeatures
#   ✓ PolyesterWeave
#   ✓ StaticArrayInterface → StaticArrayInterfaceOffsetArraysExt
#   ✓ CloseOpenIntervals
#   ✓ LayoutPointers
#   ✓ VectorizationBase
#   ✓ SLEEFPirates
#   ✓ LoopVectorization
#   ✓ LoopVectorization → SpecialFunctionsExt
#   ✓ DynamicExpressions → DynamicExpressionsLoopVectorizationExt
#   22 dependencies successfully precompiled in 20 seconds. 81 already precompiled.
#   No Changes to `~/Development/AI Lab/DSO/.venv/julia_env/Project.toml`
#   No Changes to `~/Development/AI Lab/DSO/.venv/julia_env/Manifest.toml`
# [ Info: Started!
# Expressions evaluated per second: 5.800e+02
# Head worker occupation: 59.4%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 58 / 600 total iterations (9.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.636e-01  1.594e+01  y = 0.47713
# 2           4.913e-03  3.506e+00  y = sin(0.078873)
# 3           2.296e-03  7.608e-01  y = 0.12887 / x₀
# 5           4.055e-04  8.669e-01  y = inv(sqrt(exp(exp(x₀))))
# 6           9.487e-05  1.453e+00  y = sin(inv(exp(1.3803 * x₀)))
# 7           8.779e-05  7.764e-02  y = sin(inv(exp(x₀ / cos(0.78315))))
# 8           4.430e-05  6.839e-01  y = (sin(sin(x₀)) / exp(x₀)) / x₀
# 9           2.481e-06  2.882e+00  y = (sin(x₀) / (exp(x₀) - -0.70019)) / x₀
# 10          2.471e-06  4.247e-03  y = sin((sin(x₀) / (0.68632 + exp(x₀))) / x₀)
# 11          2.444e-06  1.105e-02  y = sin((sin(x₀) / (exp(-0.39198) + exp(x₀))) / x₀)
# 16          1.624e-06  8.176e-02  y = sin(inv((exp(x₀) / sin(x₀)) * ((1.0383 / (exp(1.1292) + x₀...
#                                   )) + x₀)))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.560e+02
# Head worker occupation: 45.0%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 136 / 600 total iterations (22.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.636e-01  1.594e+01  y = 0.47713
# 2           4.913e-03  3.506e+00  y = sin(0.078873)
# 3           1.819e-03  9.937e-01  y = 0.16217 / x₀
# 4           7.661e-04  8.648e-01  y = 0.64799 / exp(x₀)
# 5           3.121e-04  8.979e-01  y = (0.25961 / x₀) / x₀
# 6           2.507e-05  2.522e+00  y = sin(0.40856 / x₀) + -0.14371
# 9           2.481e-06  7.710e-01  y = (sin(x₀) / (exp(x₀) - -0.70019)) / x₀
# 10          2.471e-06  4.247e-03  y = sin((sin(x₀) / (0.68632 + exp(x₀))) / x₀)
# 11          2.438e-06  1.340e-02  y = sin((sin(x₀) / (exp(x₀) + sin(0.74728))) / x₀)
# 12          1.928e-06  2.348e-01  y = sin(sin(x₀) / ((exp(x₀) * (x₀ / 0.90312)) + 0.3725))
# 14          1.920e-06  1.874e-03  y = sin((sin(x₀) / (exp(x₀) - sin(-0.70019 / sin(x₀)))) / x₀)
# 16          9.760e-07  3.385e-01  y = sin(inv(((exp(sqrt(x₀) / inv(x₀)) + 0.38713) + 0.9769) / x...
#                                   ₀) / x₀)
# 17          7.840e-07  2.190e-01  y = sin(sin(inv(((exp(sqrt(x₀) / inv(x₀)) + 0.38713) + 0.9769)...
#                                    / x₀) / x₀))
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.920e+02
# Head worker occupation: 44.6%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 211 / 600 total iterations (35.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.636e-01  1.594e+01  y = 0.47713
# 2           4.913e-03  3.506e+00  y = sin(0.078873)
# 3           1.819e-03  9.937e-01  y = 0.16217 / x₀
# 4           7.661e-04  8.648e-01  y = 0.64799 / exp(x₀)
# 5           3.672e-05  3.038e+00  y = (0.40856 / x₀) + -0.14371
# 6           2.507e-05  3.814e-01  y = sin(0.40856 / x₀) + -0.14371
# 9           2.481e-06  7.710e-01  y = (sin(x₀) / (exp(x₀) - -0.70019)) / x₀
# 10          2.471e-06  4.247e-03  y = sin((sin(x₀) / (0.68632 + exp(x₀))) / x₀)
# 11          2.438e-06  1.340e-02  y = sin((sin(x₀) / (exp(x₀) + sin(0.74728))) / x₀)
# 12          1.928e-06  2.348e-01  y = sin(sin(x₀) / ((exp(x₀) * (x₀ / 0.90312)) + 0.3725))
# 13          1.321e-06  3.777e-01  y = sin(inv((exp(x₀ * sqrt(x₀)) - -0.16349) + (0.9325 / 0.7854...
#                                   3)))
# 16          9.760e-07  1.010e-01  y = sin(inv(((exp(sqrt(x₀) / inv(x₀)) + 0.38713) + 0.9769) / x...
#                                   ₀) / x₀)
# 17          7.840e-07  2.190e-01  y = sin(sin(inv(((exp(sqrt(x₀) / inv(x₀)) + 0.38713) + 0.9769)...
#                                    / x₀) / x₀))
# 19          6.696e-07  7.890e-02  y = sin(sin(sin(sin(inv((inv(sqrt(0.63297)) + exp(sqrt(x₀) / i...
#                                   nv(x₀))) / x₀)))) / x₀)
# 20          3.735e-08  2.886e+00  y = sin(sin(sin(inv((inv(sqrt(0.61832)) + exp(sqrt(x₀) / inv(x...
#                                   ₀))) / x₀))) / x₀) - 0.00092443
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 6.970e+02
# Head worker occupation: 53.0%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 280 / 600 total iterations (46.667%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.636e-01  1.594e+01  y = 0.47713
# 2           4.913e-03  3.506e+00  y = sin(0.078873)
# 3           1.819e-03  9.937e-01  y = 0.16217 / x₀
# 4           7.209e-04  9.255e-01  y = 0.63947 / exp(x₀)
# 5           3.672e-05  2.977e+00  y = (0.40856 / x₀) + -0.14371
# 6           2.507e-05  3.814e-01  y = sin(0.40856 / x₀) + -0.14371
# 7           2.487e-05  8.298e-03  y = sin(0.40856 / x₀) + sin(-0.14371)
# 9           2.481e-06  1.152e+00  y = (sin(x₀) / (exp(x₀) - -0.70019)) / x₀
# 10          2.000e-06  2.157e-01  y = sin((sin(x₀) / exp(x₀)) / (x₀ - -0.24102))
# 12          6.912e-07  5.312e-01  y = sin(inv(exp(0.77934) + (exp(sqrt(x₀) * x₀) - 0.77934)))
# 13          6.710e-07  2.963e-02  y = sin(inv(exp(sqrt(x₀) * x₀) - ((x₀ - x₀) - 1.3931)))
# 18          6.126e-07  1.822e-02  y = sin(sin(inv(((exp(x₀ * sqrt(x₀)) - (-0.16349 - sqrt(sqrt(x...
#                                   ₀)))) + -0.43146) - -0.57006)))
# 19          4.965e-07  2.101e-01  y = (sin(sin(inv((inv(sqrt(0.61832)) + exp(sqrt(x₀) / inv(x₀))...
#                                   ) / x₀))) / x₀) - 0.00092443
# 20          3.735e-08  2.587e+00  y = sin(sin(sin(inv((inv(sqrt(0.61832)) + exp(sqrt(x₀) / inv(x...
#                                   ₀))) / x₀))) / x₀) - 0.00092443
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.430e+02
# Head worker occupation: 54.5%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 349 / 600 total iterations (58.167%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.636e-01  1.594e+01  y = 0.47713
# 2           4.913e-03  3.506e+00  y = sin(0.078873)
# 3           1.813e-03  9.968e-01  y = 0.1695 / x₀
# 4           5.444e-04  1.203e+00  y = 0.58362 / exp(x₀)
# 5           3.672e-05  2.697e+00  y = (0.40856 / x₀) + -0.14371
# 6           2.507e-05  3.814e-01  y = sin(0.40856 / x₀) + -0.14371
# 7           2.487e-05  8.298e-03  y = sin(0.40856 / x₀) + sin(-0.14371)
# 8           2.449e-05  1.527e-02  y = sin((-0.58342 / (x₀ * -1.4709)) + -0.13915)
# 9           2.481e-06  2.290e+00  y = (sin(x₀) / (exp(x₀) - -0.70019)) / x₀
# 10          2.000e-06  2.157e-01  y = sin((sin(x₀) / exp(x₀)) / (x₀ - -0.24102))
# 12          6.912e-07  5.312e-01  y = sin(inv(exp(0.77934) + (exp(sqrt(x₀) * x₀) - 0.77934)))
# 13          6.710e-07  2.963e-02  y = sin(inv(exp(sqrt(x₀) * x₀) - ((x₀ - x₀) - 1.3931)))
# 18          6.126e-07  1.822e-02  y = sin(sin(inv(((exp(x₀ * sqrt(x₀)) - (-0.16349 - sqrt(sqrt(x...
#                                   ₀)))) + -0.43146) - -0.57006)))
# 19          4.965e-07  2.101e-01  y = (sin(sin(inv((inv(sqrt(0.61832)) + exp(sqrt(x₀) / inv(x₀))...
#                                   ) / x₀))) / x₀) - 0.00092443
# 20          3.735e-08  2.587e+00  y = sin(sin(sin(inv((inv(sqrt(0.61832)) + exp(sqrt(x₀) / inv(x...
#                                   ₀))) / x₀))) / x₀) - 0.00092443
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.570e+02
# Head worker occupation: 54.9%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 422 / 600 total iterations (70.333%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.636e-01  1.594e+01  y = 0.47713
# 2           4.913e-03  3.506e+00  y = sin(0.078873)
# 3           1.812e-03  9.976e-01  y = 0.16826 / x₀
# 4           5.444e-04  1.202e+00  y = 0.58362 / exp(x₀)
# 5           3.672e-05  2.697e+00  y = (0.40856 / x₀) + -0.14371
# 6           2.474e-05  3.949e-01  y = sin((0.39536 / x₀) + -0.13876)
# 8           2.449e-05  5.044e-03  y = sin((-0.58342 / (x₀ * -1.4709)) + -0.13915)
# 9           2.481e-06  2.290e+00  y = (sin(x₀) / (exp(x₀) - -0.70019)) / x₀
# 10          8.603e-07  1.059e+00  y = sin(inv(exp(x₀ * sqrt(x₀)) - inv(-0.70605)))
# 11          7.978e-07  7.538e-02  y = sin(inv((exp(x₀ * sqrt(x₀)) - -0.70605) - -0.70605))
# 12          6.912e-07  1.435e-01  y = sin(inv(exp(0.77934) + (exp(sqrt(x₀) * x₀) - 0.77934)))
# 13          6.710e-07  2.963e-02  y = sin(inv(exp(sqrt(x₀) * x₀) - ((x₀ - x₀) - 1.3931)))
# 14          6.262e-07  6.908e-02  y = sin(inv(exp(x₀ * sqrt(x₀)) - ((-0.37404 / x₀) - sqrt(x₀)))...
#                                   )
# 15          4.621e-07  3.039e-01  y = sin(inv(exp(x₀ * sqrt(x₀)) - ((sqrt(x₀) / sin(x₀)) * -1.15...
#                                   94)))
# 19          3.581e-07  6.371e-02  y = sin(sin(inv((inv(cos(0.68247)) + exp(sqrt(x₀) / inv(x₀))) ...
#                                   / x₀)) / x₀) - 0.00092443
# 20          3.735e-08  2.260e+00  y = sin(sin(sin(inv((inv(sqrt(0.61832)) + exp(sqrt(x₀) / inv(x...
#                                   ₀))) / x₀))) / x₀) - 0.00092443
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.750e+02
# Head worker occupation: 58.1%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 503 / 600 total iterations (83.833%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.636e-01  1.594e+01  y = 0.47713
# 2           4.913e-03  3.506e+00  y = sin(0.078873)
# 3           1.812e-03  9.976e-01  y = 0.16826 / x₀
# 4           5.444e-04  1.202e+00  y = 0.58362 / exp(x₀)
# 5           3.672e-05  2.697e+00  y = (0.40856 / x₀) + -0.14371
# 6           2.474e-05  3.949e-01  y = sin((0.39536 / x₀) + -0.13876)
# 7           2.444e-05  1.204e-02  y = sin((0.39536 / x₀) + sin(-0.13876))
# 9           2.481e-06  1.144e+00  y = (sin(x₀) / (exp(x₀) - -0.70019)) / x₀
# 10          8.603e-07  1.059e+00  y = sin(inv(exp(x₀ * sqrt(x₀)) - inv(-0.70605)))
# 11          6.855e-07  2.272e-01  y = sin(inv(exp(sqrt(x₀) * x₀) - (-0.49959 / 0.36025)))
# 13          6.710e-07  1.066e-02  y = sin(inv(exp(sqrt(x₀) * x₀) - ((x₀ - x₀) - 1.3931)))
# 14          4.047e-07  5.057e-01  y = inv(exp(sqrt(x₀) * x₀) + (sqrt(sin(0.41911)) - -0.68299)) ...
#                                   / 1.0201
# 15          3.521e-07  1.391e-01  y = sin(inv((exp(x₀ * sqrt(x₀)) - 0.50265) + (0.62857 - -1.164...
#                                   8))) / 1.0201
# 19          3.251e-07  1.995e-02  y = sin(sin(inv(0.43998 + (sin(sqrt(sqrt(inv(x₀)))) - (inv(-0....
#                                   97479) * exp(x₀ * sqrt(x₀)))))))
# 20          3.735e-08  2.164e+00  y = sin(sin(sin(inv((inv(sqrt(0.61832)) + exp(sqrt(x₀) / inv(x...
#                                   ₀))) / x₀))) / x₀) - 0.00092443
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 7.920e+02
# Head worker occupation: 59.2%. This is high, and will prevent efficient resource usage. Increase `ncycles_per_iteration` to reduce load on head worker.
# Progress: 582 / 600 total iterations (97.000%)
# ====================================================================================================
# Hall of Fame:
# ---------------------------------------------------------------------------------------------------
# Complexity  Loss       Score     Equation
# 1           1.636e-01  1.594e+01  y = 0.47713
# 2           4.913e-03  3.506e+00  y = sin(0.078873)
# 3           1.812e-03  9.976e-01  y = 0.16826 / x₀
# 4           5.444e-04  1.202e+00  y = 0.58362 / exp(x₀)
# 5           3.497e-05  2.745e+00  y = -0.14735 + (0.40856 / x₀)
# 6           2.474e-05  3.461e-01  y = sin((0.39536 / x₀) + -0.13876)
# 7           2.444e-05  1.204e-02  y = sin((0.39536 / x₀) + sin(-0.13876))
# 8           2.161e-05  1.231e-01  y = (inv(exp(x₀)) / inv(0.78672)) - 0.046768
# 9           2.481e-06  2.164e+00  y = (sin(x₀) / (exp(x₀) - -0.70019)) / x₀
# 10          8.603e-07  1.059e+00  y = sin(inv(exp(x₀ * sqrt(x₀)) - inv(-0.70605)))
# 11          6.855e-07  2.272e-01  y = sin(inv(exp(sqrt(x₀) * x₀) - (-0.49959 / 0.36025)))
# 13          6.710e-07  1.066e-02  y = sin(inv(exp(sqrt(x₀) * x₀) - ((x₀ - x₀) - 1.3931)))
# 14          4.047e-07  5.057e-01  y = inv(exp(sqrt(x₀) * x₀) + (sqrt(sin(0.41911)) - -0.68299)) ...
#                                   / 1.0201
# 15          8.595e-08  1.549e+00  y = sin(inv(sqrt(exp(((inv(x₀) + x₀) + (inv(x₀) / 1.2088)) * x...
#                                   ₀))))
# 20          3.735e-08  1.667e-01  y = sin(sin(sin(inv((inv(sqrt(0.61832)) + exp(sqrt(x₀) / inv(x...
#                                   ₀))) / x₀))) / x₀) - 0.00092443
# ---------------------------------------------------------------------------------------------------
# ====================================================================================================
# Press 'q' and then <enter> to stop execution early.
# PySRRegressor.equations_ = [
# 	    pick     score                                           equation  \
# 	0         0.000000                                         0.47712913
# 	1         3.505567                                    sin(0.07887315)
# 	2         0.997645                                    0.16825546 / x0
# 	3         1.202310                               0.58362263 / exp(x0)
# 	4         2.745324                     -0.14735486 + (0.4085565 / x0)
# 	5         0.346102                sin((0.3953635 / x0) + -0.13876131)
# 	6         0.012037           sin((0.3953635 / x0) + sin(-0.13876131))
# 	7         0.123063       (inv(exp(x0)) / inv(0.7867192)) - 0.04676809
# 	8         2.164500            (sin(x0) / (exp(x0) - -0.7001883)) / x0
# 	9         1.059205     sin(inv(exp(x0 * sqrt(x0)) - inv(-0.7060522)))
# 	10        0.227204  sin(inv(exp(sqrt(x0) * x0) - (-0.49958715 / 0....
# 	11        0.010655  sin(inv(exp(sqrt(x0) * x0) - ((x0 - x0) - 1.39...
# 	12        0.505711  inv(exp(sqrt(x0) * x0) + (sqrt(sin(0.41910994)...
# 	13        1.549286  sin(inv(sqrt(exp(((inv(x0) + x0) + (inv(x0) / ...
# 	14  >>>>  0.166672  sin(sin(sin(inv((inv(sqrt(0.618324)) + exp(sqr...
#
# 	            loss  complexity
# 	0   1.636185e-01           1
# 	1   4.913424e-03           2
# 	2   1.811809e-03           3
# 	3   5.444475e-04           4
# 	4   3.496849e-05           5
# 	5   2.473813e-05           6
# 	6   2.444214e-05           7
# 	7   2.161194e-05           8
# 	8   2.481208e-06           9
# 	9   8.603127e-07          10
# 	10  6.854610e-07          11
# 	11  6.710082e-07          13
# 	12  4.046696e-07          14
# 	13  8.595161e-08          15
# 	14  3.735343e-08          20
# ]

# %%
model.equations["equation"].iloc[14]
# Out:
# /Users/alialh/Development/AI Lab/DSO/.venv/lib/python3.8/site-packages/pysr/sr.py:1172: FutureWarning: PySRRegressor.equations is now deprecated. Please use PySRRegressor.equations_ instead.
#   warnings.warn(
# 'sin(sin(sin(inv((inv(sqrt(0.618324)) + exp(sqrt(x0) / inv(x0))) / x0))) / x0) - 0.0009244262'
